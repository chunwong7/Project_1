# %%
#Import modules
import csv
import os
import requests
from pprint import pprint
import pandas as pd
import numpy as np

# %%
#Fema api only return 1000 rows at once, this particular file has over 167000 rows

url = "https://www.fema.gov/api/open/v1/PublicAssistanceFundedProjectsSummaries?$top=1000"
response = requests.get(url)
data_json = response.json()
#Going through the first 1000 rows
disaster1 = []
disaster_df1 = pd.DataFrame(data_json['PublicAssistanceFundedProjectsSummaries'])

# %%
#disaster_df1.head()
#specifying the search: after looking into the data, the data we need are the disaster number,
#state, declaration data, incident type, county, and federal obligated amount
dictionary = {
    'number': [],
    'state': [],
    'county': [],
    'declareDate': [],
    'type': [],
    'amount': []
}

for x in range(len(disaster_df1)):
    dictionary['number'].append(disaster_df1['disasterNumber'][x])
    dictionary['state'].append(disaster_df1['state'][x])
    dictionary['county'].append(disaster_df1['county'][x])
    dictionary['declareDate'].append(disaster_df1['declarationDate'][x])
    dictionary['type'].append(disaster_df1['incidentType'][x])
    dictionary['amount'].append(disaster_df1['federalObligatedAmount'][x])

# %%
#retreiving all of the data
#Var skips is used to go through all of the rows 
#because this particular dataset has so much data, we broke the data into two sets

skips = np.arange(1, 85, 1)
skips = skips * 1000
for x in range(len(skips)):
    url = f"https://www.fema.gov/api/open/v1/PublicAssistanceFundedProjectsSummaries?$top=1000&$skip={skips[x]}"
    response = requests.get(url)
    data_json = response.json()
    disaster_df2 = pd.DataFrame(data_json['PublicAssistanceFundedProjectsSummaries'])
    #print(disaster_df2)
    #disaster_df1 = disaster_df1.append(disaster_df2)
    for y in range(len(disaster_df1)):
        try:
            dictionary['number'].append(disaster_df2['disasterNumber'][y])
        except KeyError:
            dictionary['number'].append('NaN')
        try: 
            dictionary['state'].append(disaster_df2['state'][y])
        except KeyError:
            dictionary['state'].append('NaN')
        try:    
            dictionary['county'].append(disaster_df2['county'][y])
        except KeyError:  
            dictionary['county'].append('NaN')
        try:
            dictionary['declareDate'].append(disaster_df2['declarationDate'][y])
        except KeyError:
            dictionary['declareDate'].append('NaN')
        try:
            dictionary['type'].append(disaster_df2['incidentType'][y])
        except KeyError:    
            dictionary['type'].append('NaN')
        try:
            dictionary['amount'].append(disaster_df2['federalObligatedAmount'][y])
        except KeyError:
            dictionary['amount'].append('NaN')
    print(url)
# Out:
# https://www.fema.gov/api/open/v1/PublicAssistanceFundedProjectsSummaries?$top=1000&$skip=1000
# https://www.fema.gov/api/open/v1/PublicAssistanceFundedProjectsSummaries?$top=1000&$skip=2000
# https://www.fema.gov/api/open/v1/PublicAssistanceFundedProjectsSummaries?$top=1000&$skip=3000
# https://www.fema.gov/api/open/v1/PublicAssistanceFundedProjectsSummaries?$top=1000&$skip=4000
# https://www.fema.gov/api/open/v1/PublicAssistanceFundedProjectsSummaries?$top=1000&$skip=5000
# https://www.fema.gov/api/open/v1/PublicAssistanceFundedProjectsSummaries?$top=1000&$skip=6000
# https://www.fema.gov/api/open/v1/PublicAssistanceFundedProjectsSummaries?$top=1000&$skip=7000
# https://www.fema.gov/api/open/v1/PublicAssistanceFundedProjectsSummaries?$top=1000&$skip=8000
# https://www.fema.gov/api/open/v1/PublicAssistanceFundedProjectsSummaries?$top=1000&$skip=9000
# https://www.fema.gov/api/open/v1/PublicAssistanceFundedProjectsSummaries?$top=1000&$skip=10000
# https://www.fema.gov/api/open/v1/PublicAssistanceFundedProjectsSummaries?$top=1000&$skip=11000
# https://www.fema.gov/api/open/v1/PublicAssistanceFundedProjectsSummaries?$top=1000&$skip=12000
# https://www.fema.gov/api/open/v1/PublicAssistanceFundedProjectsSummaries?$top=1000&$skip=13000
# https://www.fema.gov/api/open/v1/PublicAssistanceFundedProjectsSummaries?$top=1000&$skip=14000
# https://www.fema.gov/api/open/v1/PublicAssistanceFundedProjectsSummaries?$top=1000&$skip=15000
# https://www.fema.gov/api/open/v1/PublicAssistanceFundedProjectsSummaries?$top=1000&$skip=16000
# https://www.fema.gov/api/open/v1/PublicAssistanceFundedProjectsSummaries?$top=1000&$skip=17000
# https://www.fema.gov/api/open/v1/PublicAssistanceFundedProjectsSummaries?$top=1000&$skip=18000
# https://www.fema.gov/api/open/v1/PublicAssistanceFundedProjectsSummaries?$top=1000&$skip=19000
# https://www.fema.gov/api/open/v1/PublicAssistanceFundedProjectsSummaries?$top=1000&$skip=20000
# https://www.fema.gov/api/open/v1/PublicAssistanceFundedProjectsSummaries?$top=1000&$skip=21000
# https://www.fema.gov/api/open/v1/PublicAssistanceFundedProjectsSummaries?$top=1000&$skip=22000
# https://www.fema.gov/api/open/v1/PublicAssistanceFundedProjectsSummaries?$top=1000&$skip=23000
# https://www.fema.gov/api/open/v1/PublicAssistanceFundedProjectsSummaries?$top=1000&$skip=24000
# https://www.fema.gov/api/open/v1/PublicAssistanceFundedProjectsSummaries?$top=1000&$skip=25000
# https://www.fema.gov/api/open/v1/PublicAssistanceFundedProjectsSummaries?$top=1000&$skip=26000
# https://www.fema.gov/api/open/v1/PublicAssistanceFundedProjectsSummaries?$top=1000&$skip=27000
# https://www.fema.gov/api/open/v1/PublicAssistanceFundedProjectsSummaries?$top=1000&$skip=28000
# https://www.fema.gov/api/open/v1/PublicAssistanceFundedProjectsSummaries?$top=1000&$skip=29000
# https://www.fema.gov/api/open/v1/PublicAssistanceFundedProjectsSummaries?$top=1000&$skip=30000
# https://www.fema.gov/api/open/v1/PublicAssistanceFundedProjectsSummaries?$top=1000&$skip=31000
# https://www.fema.gov/api/open/v1/PublicAssistanceFundedProjectsSummaries?$top=1000&$skip=32000
# https://www.fema.gov/api/open/v1/PublicAssistanceFundedProjectsSummaries?$top=1000&$skip=33000
# https://www.fema.gov/api/open/v1/PublicAssistanceFundedProjectsSummaries?$top=1000&$skip=34000
# https://www.fema.gov/api/open/v1/PublicAssistanceFundedProjectsSummaries?$top=1000&$skip=35000
# https://www.fema.gov/api/open/v1/PublicAssistanceFundedProjectsSummaries?$top=1000&$skip=36000
# https://www.fema.gov/api/open/v1/PublicAssistanceFundedProjectsSummaries?$top=1000&$skip=37000
# https://www.fema.gov/api/open/v1/PublicAssistanceFundedProjectsSummaries?$top=1000&$skip=38000
# https://www.fema.gov/api/open/v1/PublicAssistanceFundedProjectsSummaries?$top=1000&$skip=39000
# https://www.fema.gov/api/open/v1/PublicAssistanceFundedProjectsSummaries?$top=1000&$skip=40000
# https://www.fema.gov/api/open/v1/PublicAssistanceFundedProjectsSummaries?$top=1000&$skip=41000
# https://www.fema.gov/api/open/v1/PublicAssistanceFundedProjectsSummaries?$top=1000&$skip=42000
# https://www.fema.gov/api/open/v1/PublicAssistanceFundedProjectsSummaries?$top=1000&$skip=43000
# https://www.fema.gov/api/open/v1/PublicAssistanceFundedProjectsSummaries?$top=1000&$skip=44000
# https://www.fema.gov/api/open/v1/PublicAssistanceFundedProjectsSummaries?$top=1000&$skip=45000
# https://www.fema.gov/api/open/v1/PublicAssistanceFundedProjectsSummaries?$top=1000&$skip=46000
# https://www.fema.gov/api/open/v1/PublicAssistanceFundedProjectsSummaries?$top=1000&$skip=47000
# https://www.fema.gov/api/open/v1/PublicAssistanceFundedProjectsSummaries?$top=1000&$skip=48000
# https://www.fema.gov/api/open/v1/PublicAssistanceFundedProjectsSummaries?$top=1000&$skip=49000
# https://www.fema.gov/api/open/v1/PublicAssistanceFundedProjectsSummaries?$top=1000&$skip=50000
# https://www.fema.gov/api/open/v1/PublicAssistanceFundedProjectsSummaries?$top=1000&$skip=51000
# https://www.fema.gov/api/open/v1/PublicAssistanceFundedProjectsSummaries?$top=1000&$skip=52000
# https://www.fema.gov/api/open/v1/PublicAssistanceFundedProjectsSummaries?$top=1000&$skip=53000
# https://www.fema.gov/api/open/v1/PublicAssistanceFundedProjectsSummaries?$top=1000&$skip=54000
# https://www.fema.gov/api/open/v1/PublicAssistanceFundedProjectsSummaries?$top=1000&$skip=55000
# https://www.fema.gov/api/open/v1/PublicAssistanceFundedProjectsSummaries?$top=1000&$skip=56000
# https://www.fema.gov/api/open/v1/PublicAssistanceFundedProjectsSummaries?$top=1000&$skip=57000
# https://www.fema.gov/api/open/v1/PublicAssistanceFundedProjectsSummaries?$top=1000&$skip=58000
# https://www.fema.gov/api/open/v1/PublicAssistanceFundedProjectsSummaries?$top=1000&$skip=59000
# https://www.fema.gov/api/open/v1/PublicAssistanceFundedProjectsSummaries?$top=1000&$skip=60000
# https://www.fema.gov/api/open/v1/PublicAssistanceFundedProjectsSummaries?$top=1000&$skip=61000
# https://www.fema.gov/api/open/v1/PublicAssistanceFundedProjectsSummaries?$top=1000&$skip=62000
# https://www.fema.gov/api/open/v1/PublicAssistanceFundedProjectsSummaries?$top=1000&$skip=63000
# https://www.fema.gov/api/open/v1/PublicAssistanceFundedProjectsSummaries?$top=1000&$skip=64000
# https://www.fema.gov/api/open/v1/PublicAssistanceFundedProjectsSummaries?$top=1000&$skip=65000
# https://www.fema.gov/api/open/v1/PublicAssistanceFundedProjectsSummaries?$top=1000&$skip=66000
# https://www.fema.gov/api/open/v1/PublicAssistanceFundedProjectsSummaries?$top=1000&$skip=67000
# https://www.fema.gov/api/open/v1/PublicAssistanceFundedProjectsSummaries?$top=1000&$skip=68000
# https://www.fema.gov/api/open/v1/PublicAssistanceFundedProjectsSummaries?$top=1000&$skip=69000
# https://www.fema.gov/api/open/v1/PublicAssistanceFundedProjectsSummaries?$top=1000&$skip=70000
# https://www.fema.gov/api/open/v1/PublicAssistanceFundedProjectsSummaries?$top=1000&$skip=71000
# https://www.fema.gov/api/open/v1/PublicAssistanceFundedProjectsSummaries?$top=1000&$skip=72000
# https://www.fema.gov/api/open/v1/PublicAssistanceFundedProjectsSummaries?$top=1000&$skip=73000
# https://www.fema.gov/api/open/v1/PublicAssistanceFundedProjectsSummaries?$top=1000&$skip=74000
# https://www.fema.gov/api/open/v1/PublicAssistanceFundedProjectsSummaries?$top=1000&$skip=75000
# https://www.fema.gov/api/open/v1/PublicAssistanceFundedProjectsSummaries?$top=1000&$skip=76000
# https://www.fema.gov/api/open/v1/PublicAssistanceFundedProjectsSummaries?$top=1000&$skip=77000
# https://www.fema.gov/api/open/v1/PublicAssistanceFundedProjectsSummaries?$top=1000&$skip=78000
# https://www.fema.gov/api/open/v1/PublicAssistanceFundedProjectsSummaries?$top=1000&$skip=79000
# https://www.fema.gov/api/open/v1/PublicAssistanceFundedProjectsSummaries?$top=1000&$skip=80000
# https://www.fema.gov/api/open/v1/PublicAssistanceFundedProjectsSummaries?$top=1000&$skip=81000
# https://www.fema.gov/api/open/v1/PublicAssistanceFundedProjectsSummaries?$top=1000&$skip=82000
# https://www.fema.gov/api/open/v1/PublicAssistanceFundedProjectsSummaries?$top=1000&$skip=83000
# https://www.fema.gov/api/open/v1/PublicAssistanceFundedProjectsSummaries?$top=1000&$skip=84000

# %%
skips = np.arange(85, 168, 1)
skips = skips * 1000
dictionary2 = {
    'number': [],
    'state': [],
    'county': [],
    'declareDate': [],
    'type': [],
    'amount': []
}
for x in range(len(skips)):
    url = f"https://www.fema.gov/api/open/v1/PublicAssistanceFundedProjectsSummaries?$top=1000&$skip={skips[x]}"
    response = requests.get(url)
    data_json = response.json()
    disaster_df2 = pd.DataFrame(data_json['PublicAssistanceFundedProjectsSummaries'])
    for y in range(len(disaster_df2)):
        try:
            dictionary2['number'].append(disaster_df2['disasterNumber'][y])
        except KeyError:
            dictionary2['number'].append('NaN')
        try: 
            dictionary2['state'].append(disaster_df2['state'][y])
        except KeyError:
            dictionary2['state'].append('NaN')
        try:    
            dictionary2['county'].append(disaster_df2['county'][y])
        except KeyError:  
            dictionary2['county'].append('NaN')
        try:
            dictionary2['declareDate'].append(disaster_df2['declarationDate'][y])
        except KeyError:
            dictionary2['declareDate'].append('NaN')
        try:
            dictionary2['type'].append(disaster_df2['incidentType'][y])
        except KeyError:    
            dictionary2['type'].append('NaN')
        try:
            dictionary2['amount'].append(disaster_df2['federalObligatedAmount'][y])
        except KeyError:
            dictionary2['amount'].append('NaN')
    
    print(url)
# Out:
# https://www.fema.gov/api/open/v1/PublicAssistanceFundedProjectsSummaries?$top=1000&$skip=85000
# https://www.fema.gov/api/open/v1/PublicAssistanceFundedProjectsSummaries?$top=1000&$skip=86000
# https://www.fema.gov/api/open/v1/PublicAssistanceFundedProjectsSummaries?$top=1000&$skip=87000
# https://www.fema.gov/api/open/v1/PublicAssistanceFundedProjectsSummaries?$top=1000&$skip=88000
# https://www.fema.gov/api/open/v1/PublicAssistanceFundedProjectsSummaries?$top=1000&$skip=89000
# https://www.fema.gov/api/open/v1/PublicAssistanceFundedProjectsSummaries?$top=1000&$skip=90000
# https://www.fema.gov/api/open/v1/PublicAssistanceFundedProjectsSummaries?$top=1000&$skip=91000
# https://www.fema.gov/api/open/v1/PublicAssistanceFundedProjectsSummaries?$top=1000&$skip=92000
# https://www.fema.gov/api/open/v1/PublicAssistanceFundedProjectsSummaries?$top=1000&$skip=93000
# https://www.fema.gov/api/open/v1/PublicAssistanceFundedProjectsSummaries?$top=1000&$skip=94000
# https://www.fema.gov/api/open/v1/PublicAssistanceFundedProjectsSummaries?$top=1000&$skip=95000
# https://www.fema.gov/api/open/v1/PublicAssistanceFundedProjectsSummaries?$top=1000&$skip=96000
# https://www.fema.gov/api/open/v1/PublicAssistanceFundedProjectsSummaries?$top=1000&$skip=97000
# https://www.fema.gov/api/open/v1/PublicAssistanceFundedProjectsSummaries?$top=1000&$skip=98000
# https://www.fema.gov/api/open/v1/PublicAssistanceFundedProjectsSummaries?$top=1000&$skip=99000
# https://www.fema.gov/api/open/v1/PublicAssistanceFundedProjectsSummaries?$top=1000&$skip=100000
# https://www.fema.gov/api/open/v1/PublicAssistanceFundedProjectsSummaries?$top=1000&$skip=101000
# https://www.fema.gov/api/open/v1/PublicAssistanceFundedProjectsSummaries?$top=1000&$skip=102000
# https://www.fema.gov/api/open/v1/PublicAssistanceFundedProjectsSummaries?$top=1000&$skip=103000
# https://www.fema.gov/api/open/v1/PublicAssistanceFundedProjectsSummaries?$top=1000&$skip=104000
# https://www.fema.gov/api/open/v1/PublicAssistanceFundedProjectsSummaries?$top=1000&$skip=105000
# https://www.fema.gov/api/open/v1/PublicAssistanceFundedProjectsSummaries?$top=1000&$skip=106000
# https://www.fema.gov/api/open/v1/PublicAssistanceFundedProjectsSummaries?$top=1000&$skip=107000
# https://www.fema.gov/api/open/v1/PublicAssistanceFundedProjectsSummaries?$top=1000&$skip=108000
# https://www.fema.gov/api/open/v1/PublicAssistanceFundedProjectsSummaries?$top=1000&$skip=109000
# https://www.fema.gov/api/open/v1/PublicAssistanceFundedProjectsSummaries?$top=1000&$skip=110000
# https://www.fema.gov/api/open/v1/PublicAssistanceFundedProjectsSummaries?$top=1000&$skip=111000
# https://www.fema.gov/api/open/v1/PublicAssistanceFundedProjectsSummaries?$top=1000&$skip=112000
# https://www.fema.gov/api/open/v1/PublicAssistanceFundedProjectsSummaries?$top=1000&$skip=113000
# https://www.fema.gov/api/open/v1/PublicAssistanceFundedProjectsSummaries?$top=1000&$skip=114000
# https://www.fema.gov/api/open/v1/PublicAssistanceFundedProjectsSummaries?$top=1000&$skip=115000
# https://www.fema.gov/api/open/v1/PublicAssistanceFundedProjectsSummaries?$top=1000&$skip=116000
# https://www.fema.gov/api/open/v1/PublicAssistanceFundedProjectsSummaries?$top=1000&$skip=117000
# https://www.fema.gov/api/open/v1/PublicAssistanceFundedProjectsSummaries?$top=1000&$skip=118000
# https://www.fema.gov/api/open/v1/PublicAssistanceFundedProjectsSummaries?$top=1000&$skip=119000
# https://www.fema.gov/api/open/v1/PublicAssistanceFundedProjectsSummaries?$top=1000&$skip=120000
# https://www.fema.gov/api/open/v1/PublicAssistanceFundedProjectsSummaries?$top=1000&$skip=121000
# https://www.fema.gov/api/open/v1/PublicAssistanceFundedProjectsSummaries?$top=1000&$skip=122000
# https://www.fema.gov/api/open/v1/PublicAssistanceFundedProjectsSummaries?$top=1000&$skip=123000
# https://www.fema.gov/api/open/v1/PublicAssistanceFundedProjectsSummaries?$top=1000&$skip=124000
# https://www.fema.gov/api/open/v1/PublicAssistanceFundedProjectsSummaries?$top=1000&$skip=125000
# https://www.fema.gov/api/open/v1/PublicAssistanceFundedProjectsSummaries?$top=1000&$skip=126000
# https://www.fema.gov/api/open/v1/PublicAssistanceFundedProjectsSummaries?$top=1000&$skip=127000
# https://www.fema.gov/api/open/v1/PublicAssistanceFundedProjectsSummaries?$top=1000&$skip=128000
# https://www.fema.gov/api/open/v1/PublicAssistanceFundedProjectsSummaries?$top=1000&$skip=129000
# https://www.fema.gov/api/open/v1/PublicAssistanceFundedProjectsSummaries?$top=1000&$skip=130000
# https://www.fema.gov/api/open/v1/PublicAssistanceFundedProjectsSummaries?$top=1000&$skip=131000
# https://www.fema.gov/api/open/v1/PublicAssistanceFundedProjectsSummaries?$top=1000&$skip=132000
# https://www.fema.gov/api/open/v1/PublicAssistanceFundedProjectsSummaries?$top=1000&$skip=133000
# https://www.fema.gov/api/open/v1/PublicAssistanceFundedProjectsSummaries?$top=1000&$skip=134000
# https://www.fema.gov/api/open/v1/PublicAssistanceFundedProjectsSummaries?$top=1000&$skip=135000
# https://www.fema.gov/api/open/v1/PublicAssistanceFundedProjectsSummaries?$top=1000&$skip=136000
# https://www.fema.gov/api/open/v1/PublicAssistanceFundedProjectsSummaries?$top=1000&$skip=137000
# https://www.fema.gov/api/open/v1/PublicAssistanceFundedProjectsSummaries?$top=1000&$skip=138000
# https://www.fema.gov/api/open/v1/PublicAssistanceFundedProjectsSummaries?$top=1000&$skip=139000
# https://www.fema.gov/api/open/v1/PublicAssistanceFundedProjectsSummaries?$top=1000&$skip=140000
# https://www.fema.gov/api/open/v1/PublicAssistanceFundedProjectsSummaries?$top=1000&$skip=141000
# https://www.fema.gov/api/open/v1/PublicAssistanceFundedProjectsSummaries?$top=1000&$skip=142000
# https://www.fema.gov/api/open/v1/PublicAssistanceFundedProjectsSummaries?$top=1000&$skip=143000
# https://www.fema.gov/api/open/v1/PublicAssistanceFundedProjectsSummaries?$top=1000&$skip=144000
# https://www.fema.gov/api/open/v1/PublicAssistanceFundedProjectsSummaries?$top=1000&$skip=145000
# https://www.fema.gov/api/open/v1/PublicAssistanceFundedProjectsSummaries?$top=1000&$skip=146000
# https://www.fema.gov/api/open/v1/PublicAssistanceFundedProjectsSummaries?$top=1000&$skip=147000
# https://www.fema.gov/api/open/v1/PublicAssistanceFundedProjectsSummaries?$top=1000&$skip=148000
# https://www.fema.gov/api/open/v1/PublicAssistanceFundedProjectsSummaries?$top=1000&$skip=149000
# https://www.fema.gov/api/open/v1/PublicAssistanceFundedProjectsSummaries?$top=1000&$skip=150000
# https://www.fema.gov/api/open/v1/PublicAssistanceFundedProjectsSummaries?$top=1000&$skip=151000
# https://www.fema.gov/api/open/v1/PublicAssistanceFundedProjectsSummaries?$top=1000&$skip=152000
# https://www.fema.gov/api/open/v1/PublicAssistanceFundedProjectsSummaries?$top=1000&$skip=153000
# https://www.fema.gov/api/open/v1/PublicAssistanceFundedProjectsSummaries?$top=1000&$skip=154000
# https://www.fema.gov/api/open/v1/PublicAssistanceFundedProjectsSummaries?$top=1000&$skip=155000
# https://www.fema.gov/api/open/v1/PublicAssistanceFundedProjectsSummaries?$top=1000&$skip=156000
# https://www.fema.gov/api/open/v1/PublicAssistanceFundedProjectsSummaries?$top=1000&$skip=157000
# https://www.fema.gov/api/open/v1/PublicAssistanceFundedProjectsSummaries?$top=1000&$skip=158000
# https://www.fema.gov/api/open/v1/PublicAssistanceFundedProjectsSummaries?$top=1000&$skip=159000
# https://www.fema.gov/api/open/v1/PublicAssistanceFundedProjectsSummaries?$top=1000&$skip=160000
# https://www.fema.gov/api/open/v1/PublicAssistanceFundedProjectsSummaries?$top=1000&$skip=161000
# https://www.fema.gov/api/open/v1/PublicAssistanceFundedProjectsSummaries?$top=1000&$skip=162000
# https://www.fema.gov/api/open/v1/PublicAssistanceFundedProjectsSummaries?$top=1000&$skip=163000
# https://www.fema.gov/api/open/v1/PublicAssistanceFundedProjectsSummaries?$top=1000&$skip=164000
# https://www.fema.gov/api/open/v1/PublicAssistanceFundedProjectsSummaries?$top=1000&$skip=165000
# https://www.fema.gov/api/open/v1/PublicAssistanceFundedProjectsSummaries?$top=1000&$skip=166000
# https://www.fema.gov/api/open/v1/PublicAssistanceFundedProjectsSummaries?$top=1000&$skip=167000

# %%
df1 = pd.DataFrame(dictionary)
df2 = pd.DataFrame(dictionary2)
for y in range(len(df2)):
        dictionary['number'].append(dictionary2['number'][y])
        dictionary['state'].append(dictionary2['state'][y])
        dictionary['county'].append(dictionary2['county'][y])
        dictionary['declareDate'].append(dictionary2['declareDate'][y])
        dictionary['type'].append(dictionary2['type'][y])
        dictionary['amount'].append(dictionary2['amount'][y])
df = pd.DataFrame(dictionary)

# %%
def remove(string): 
    return string.replace(" ", "")


states = df['state'].unique()


columns = ['disasterNumber', 'county', 'declarationDate', 'incidentType', 'amountOblig']
for x in range(len(states)):
    output_data_file = f"output_data/state_data/{remove(states[x])}Public.csv"
    state_df = df.loc[df['state']==states[x],:]
    state_df = state_df.set_index("state")
    print(output_data_file)
    with open(output_data_file, 'w', newline='') as csvfile:
        csvwriter = csv.writer(csvfile, delimiter=',')
        csvwriter.writerow(columns)
        for y in range(len(state_df)):
            csvwriter.writerow([state_df['number'][y], state_df['county'][y],
                               state_df['declareDate'][y], state_df['type'][y], state_df['amount'][y]])
# Out:
# output_data/state_data/TexasPublic.csv
# output_data/state_data/NorthCarolinaPublic.csv
# output_data/state_data/SouthCarolinaPublic.csv
# output_data/state_data/NewYorkPublic.csv
# output_data/state_data/VirginiaPublic.csv
# output_data/state_data/MissouriPublic.csv
# output_data/state_data/VirginIslandsoftheU.S.Public.csv
# output_data/state_data/AlabamaPublic.csv
# output_data/state_data/PuertoRicoPublic.csv
# output_data/state_data/WashingtonPublic.csv
# output_data/state_data/KansasPublic.csv
# output_data/state_data/TennesseePublic.csv
# output_data/state_data/WisconsinPublic.csv
# output_data/state_data/MississippiPublic.csv
# output_data/state_data/IowaPublic.csv
# output_data/state_data/ArkansasPublic.csv
# output_data/state_data/OklahomaPublic.csv
# output_data/state_data/MinnesotaPublic.csv
# output_data/state_data/LouisianaPublic.csv
# output_data/state_data/NorthDakotaPublic.csv
# output_data/state_data/MainePublic.csv
# output_data/state_data/PennsylvaniaPublic.csv
# output_data/state_data/ColoradoPublic.csv
# output_data/state_data/NevadaPublic.csv
# output_data/state_data/IllinoisPublic.csv
# output_data/state_data/GeorgiaPublic.csv
# output_data/state_data/NebraskaPublic.csv
# output_data/state_data/SouthDakotaPublic.csv
# output_data/state_data/UtahPublic.csv
# output_data/state_data/WyomingPublic.csv
# output_data/state_data/NewJerseyPublic.csv
# output_data/state_data/DelawarePublic.csv
# output_data/state_data/FloridaPublic.csv
# output_data/state_data/NewMexicoPublic.csv
# output_data/state_data/MarylandPublic.csv
# output_data/state_data/ConnecticutPublic.csv
# output_data/state_data/NewHampshirePublic.csv
# output_data/state_data/VermontPublic.csv
# output_data/state_data/KentuckyPublic.csv
# output_data/state_data/AlaskaPublic.csv
# output_data/state_data/WestVirginiaPublic.csv
# output_data/state_data/DistrictofColumbiaPublic.csv
# output_data/state_data/OhioPublic.csv
# output_data/state_data/HawaiiPublic.csv
# output_data/state_data/ArizonaPublic.csv
# output_data/state_data/MontanaPublic.csv
# output_data/state_data/GuamPublic.csv
# output_data/state_data/OregonPublic.csv
# output_data/state_data/MichiganPublic.csv
# output_data/state_data/FederatedStatesofMicronesiaPublic.csv
# output_data/state_data/IndianaPublic.csv
# output_data/state_data/NorthernMarianaIslandsPublic.csv
# output_data/state_data/AmericanSamoaPublic.csv
# output_data/state_data/CaliforniaPublic.csv
# output_data/state_data/IdahoPublic.csv
# output_data/state_data/MassachusettsPublic.csv
# output_data/state_data/RhodeIslandPublic.csv

# %%
df
# Out:
#         number           state       county               declareDate  \
# 0         1239           Texas    Val Verde  1998-08-26T00:00:00.000Z
# 1         1240  North Carolina          NaN  1998-08-27T00:00:00.000Z
# 2         1240  North Carolina          NaN  1998-08-27T00:00:00.000Z
# 3         1240  North Carolina          NaN  1998-08-27T00:00:00.000Z
# 4         1240  North Carolina          NaN  1998-08-27T00:00:00.000Z
# ...        ...             ...          ...                       ...
# 167769    4465  North Carolina        Jones  2019-10-04T00:00:00.000Z
# 167770    4465  North Carolina  New Hanover  2019-10-04T00:00:00.000Z
# 167771    4465  North Carolina    Statewide  2019-10-04T00:00:00.000Z
# 167772    4465  North Carolina    Statewide  2019-10-04T00:00:00.000Z
# 167773    4465  North Carolina    Statewide  2019-10-04T00:00:00.000Z
#
#                    type      amount
# 0       Severe Storm(s)    12028.63
# 1             Hurricane    30956.35
# 2             Hurricane  1288255.25
# 3             Hurricane     4125.00
# 4             Hurricane    22810.25
# ...                 ...         ...
# 167769        Hurricane    55433.83
# 167770        Hurricane   116106.49
# 167771        Hurricane    17667.96
# 167772        Hurricane    22974.38
# 167773        Hurricane    11442.58
#
# [167774 rows x 6 columns]

# %%
#checking the data

#output_data_file = f"output_data/state_data/{remove(states[3])}Public.csv"
#with open(output_data_file, 'r', newline='') as csvfile:
    #csvreader = csv.reader(csvfile, delimiter=',')
    #headers = next(csvreader)
    #dfnew = pd.DataFrame(csvreader)

#dfnew.columns = headers

#dfnew['amountOblig'] = pd.to_numeric(dfnew['amountOblig'])
#print(dfnew['amountOblig'].sum())
#state_df = df.loc[df['state']==states[3],:]
#print(state_df['amount'].sum())

# %%
statetotal = {
    'state': [],
    'totalAmount': []
}

for x in range(len(states)):
    statetotal['state'].append(states[x])
    state = states[x]
    state_csv = df.loc[df['state']==states[x], :]
    state_csv['amount'] = pd.to_numeric(state_csv['amount'])
    statesum = state_csv['amount'].sum()
    statetotal['totalAmount'].append(statesum)
# Out:
# /opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.

# %%
pd.options.display.float_format = '{:.2f}'.format
statecols = ['State', 'Total_Amount']
with open('output_data/state_total.csv', 'w', newline='') as csvfile:
    csvwriter = csv.writer(csvfile, delimiter=',')
    csvwriter.writerow(statecols)
    for x in range(len(states)):
        csvwriter.writerow([statetotal['state'][x], statetotal['totalAmount'][x]])
statetotal_df = pd.DataFrame(statetotal)

# %%
#def byCounty(data):
countytotal = {
    'county': [],
    'county_total': []
    
}

columns = ['county', 'totalamount']

for x in range(len(states)):
    state_csv = df.loc[df['state']==states[x], :]
    counties = state_csv['county'].unique()
    output_path = f'output_data/county_data/{remove(states[x])}counties.csv'
    for y in range(len(counties)):
        county_csv = state_csv.loc[state_csv['county']==counties[y], :]
        countytotal['county'].append(counties[y])
        countyamount = county_csv['amount']
        countytotal['county_total'].append(countyamount.sum())
    with open(output_path, 'w', newline='') as csvfile:
        csvwriter = csv.writer(csvfile, delimiter=',')
        csvwriter.writerow(columns)
        for z in range(len(counties)):
            csvwriter.writerow([countytotal['county'][z], countytotal['county_total'][z]])
       
    
    
    print(f'success for {states[x]} ')
# Out:
# success for Texas
# success for North Carolina
# success for South Carolina
# success for New York
# success for Virginia
# success for Missouri
# success for Virgin Islands of the U.S.
# success for Alabama
# success for Puerto Rico
# success for Washington
# success for Kansas
# success for Tennessee
# success for Wisconsin
# success for Mississippi
# success for Iowa
# success for Arkansas
# success for Oklahoma
# success for Minnesota
# success for Louisiana
# success for North Dakota
# success for Maine
# success for Pennsylvania
# success for Colorado
# success for Nevada
# success for Illinois
# success for Georgia
# success for Nebraska
# success for South Dakota
# success for Utah
# success for Wyoming
# success for New Jersey
# success for Delaware
# success for Florida
# success for New Mexico
# success for Maryland
# success for Connecticut
# success for New Hampshire
# success for Vermont
# success for Kentucky
# success for Alaska
# success for West Virginia
# success for District of Columbia
# success for Ohio
# success for Hawaii
# success for Arizona
# success for Montana
# success for Guam
# success for Oregon
# success for Michigan
# success for Federated States of Micronesia
# success for Indiana
# success for Northern Mariana Islands
# success for American Samoa
# success for California
# success for Idaho
# success for Massachusetts
# success for Rhode Island

# %%
state_csv = df.loc[df['state']==states[0], :]
counties = state_csv['county'].unique()
countytotal = {
    'county': [],
    'county_total': []
    
}
#state_csv
#for y in range(len(counties)):
county_csv = state_csv.loc[state_csv['county']==counties[0], :]
county_csv
countytotal['county'].append(counties[0])
countyamount = county_csv['amount']
#county_csv
countytotal['county_total'].append(countyamount.sum())

countytotal
# Out:
# {'county': ['Val Verde'], 'county_total': [2318814.53]}

# %%
for x in range (2):
    print(x)
# Out:
# 0
# 1
